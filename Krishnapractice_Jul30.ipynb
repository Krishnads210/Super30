# %%
# Create a falt list from below

l = [[1,2] ,[3,4,5] ,5,6,7,8,9,9, [6] , [7,8]]

falt_list = []

for i in l:
    if type(i) == list:
        for x in i:
            falt_list.append(x)
    else:
        falt_list.append(i)
falt_list
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9, 9, 6, 7, 8]

# %%
x = [1,2,3,4]
type(x)
# Out:
# list

# %%
s = 'programming'

d = {}

for i in s:
    d[i] = s.count(i)
print(d)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
d1 = {"k": 1, "l":2}

# %%
d1.values()
# Out:
# dict_values([1, 2])

# %%
# Print the person with highest marks

d =  {
    "Amit": 85,
    "Priya": 92,
    "Rahul": 78,
    "Neha": 89
}

for i,v in d.items():
    if v == max(d.values()):
        print(i)
# Out:
# Priya

# %%
# Return a dictionary like the first letter and the words as calues having the first letter

l = [
    "apple",
    "banana",
    "avocado",
    "blueberry",
    "cherry",
    "carrot"
]

d = {}

for i in l:
    list(set(i[0]))
for i in l: 
    for j in list(set(s1)): 
        if i[0] == j:
            d1[j] = i 
    print(d1)
# Out:
# ['a', 'p', 'l', 'e']

# %%
# Calculate the sum of the items in Inventory ( Price * Quantity total)

inventory = {
    "Laptop": {
        "price": 800,
        "quantity": 5
    },
    "Mouse": {
        "price": 20,
        "quantity": 15
    },
    "Keyboard": {
        "price": 40,
        "quantity": 10
    }
}

total_list = []
total = 0

for i,v in inventory.items():
    total_list.append(v['price'] * v['quantity'])
print(sum(total_list))
# Out:
# 4700

# %%
l = [10,20,30,40,4,5,3,78,49,3,5,5,3,30,40]

more_than_one = {}

for i in l:
    if l.count(i) > 1:
        more_than_one[i]  = l.count(i)

print(more_than_one)
# Out:
# {30: 2, 40: 2, 5: 3, 3: 3}
